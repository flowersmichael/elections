# %%
import pandas as pd
df = pd.read_csv("resources/independent_expenditures_2004-2020.csv")
df.head(10)
# Out:
# C:\Users\ermah\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (6,8,13,15,16,17,20,21,22,23,24,25,26,27,28,30,31,33,34,35,36,37,38,39,46,57,59,60,61,62,64,65,66,67,70,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  report_year  image_number  file_number  \
# 0           0         2020  2.020100e+17    1444283.0
# 1           1         2020  2.020100e+17    1445692.0
# 2           2         2020  2.020100e+17    1466866.0
# 3           3         2020  2.020100e+17    1466866.0
# 4           4         2020  2.020110e+17    1470736.0
# 5           5         2020  2.020100e+17    1467573.0
# 6           6         2020  2.020100e+17    1445694.0
# 7           7         2020  2.020100e+17    1445694.0
# 8           8         2020  2.020100e+17    1445694.0
# 9           9         2020  2.020100e+17    1445694.0
#
# ...

# %%
import pandas as pd
df = pd.read_csv("resources/fec-independent-expenditures.csv")
df.head(10)
# Out:
# C:\Users\ermah\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (11,12,17,22,23,24,25,26,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   committee_id                              committee_name  report_year  \
# 0    C00042366    DEMOCRATIC SENATORIAL CAMPAIGN COMMITTEE         2013
# 1    C00042622              MASSACHUSETTS REPUBLICAN PARTY         2013
# 2    C00042622              MASSACHUSETTS REPUBLICAN PARTY         2013
# 3    C00484642                         SENATE MAJORITY PAC         2013
# 4    C00486845  LEAGUE OF CONSERVATION VOTERS VICTORY FUND         2013
# 5    C00484642                         SENATE MAJORITY PAC         2013
# 6    C00484642                         SENATE MAJORITY PAC         2013
# 7    C00484642                         SENATE MAJORITY PAC         2013
# ...

# %%
import plotly.express as exp
import plotly as plt
import numpy as np

# %%
x = df.iloc[:2]
y = df.iloc [:12]
