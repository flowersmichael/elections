# %%
import pandas as pd
df = pd.read_csv("resources/fec-independent-expenditures.csv")
df.head(10)
# Out:
# C:\Users\ermah\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (8,9,10,15,16,21,24,28,29,30,31,32,35,36,44,63,64,66) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   committee_id                              committee_name  report_year  \
# 0    C00042366    DEMOCRATIC SENATORIAL CAMPAIGN COMMITTEE         2013
# 1    C00042622              MASSACHUSETTS REPUBLICAN PARTY         2013
# 2    C00042622              MASSACHUSETTS REPUBLICAN PARTY         2013
# 3    C00484642                         SENATE MAJORITY PAC         2013
# 4    C00486845  LEAGUE OF CONSERVATION VOTERS VICTORY FUND         2013
# 5    C00484642                         SENATE MAJORITY PAC         2013
# 6    C00484642                         SENATE MAJORITY PAC         2013
# 7    C00484642                         SENATE MAJORITY PAC         2013
# ...

# %%
for column in df.columns[0:]:
    print(df[column])
# Out:
# 0         C00042366
# 1         C00042622
# 2         C00042622
# 3         C00484642
# 4         C00486845
#             ...
# 413232    C90010646
# 413233    C90010646
# 413234    C90010646
# 413235    C90010646
# 413236    C90010646
# Name: committee_id, Length: 413237, dtype: object
# 0           DEMOCRATIC SENATORIAL CAMPAIGN COMMITTEE
# 1                     MASSACHUSETTS REPUBLICAN PARTY
# 2                     MASSACHUSETTS REPUBLICAN PARTY
# 3                                SENATE MAJORITY PAC
# 4         LEAGUE OF CONSERVATION VOTERS VICTORY FUND
#                              ...
# 413232                             FEMINIST MAJORITY
# 413233                             FEMINIST MAJORITY
# 413234                             FEMINIST MAJORITY
# 413235                             FEMINIST MAJORITY
# 413236                             FEMINIST MAJORITY
# Name: committee_name, Length: 413237, dtype: object
# 0         2013
# 1         2013
# 2         2013
# 3         2013
# ...
